# %%
import pandas as pd

df = pd.read_csv("extracted_data.csv", header = None)

# %%
import matplotlib.pyplot as plt

plt.scatter(df.index, df[1])

# %%
import matplotlib.pyplot as plt

# Plotting histogram of the transformed and normalized data
plt.figure(figsize=(10, 6))
plt.hist(df[1], bins=200, alpha=0.75, color='blue')
plt.title('Histogram of Log-transformed and Min-Max Normalized Data')
plt.xlabel('Normalized Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
